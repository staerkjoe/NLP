# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/NLP
# Out:
# /content/NLP

# %%
# !cp '/content/drive/MyDrive/Colab Notebooks/NaiveBayes.ipynb'
# Out:
# cp: missing destination file operand after '/content/drive/MyDrive/Colab Notebooks/NaiveBayes.ipynb.'
# Try 'cp --help' for more information.
